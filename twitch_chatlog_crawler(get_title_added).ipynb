# %%
#트위치 비디오 제목 받아지는 변수
video_title = ''

# %%
import requests 
import json
import sys


def doubleDigit(num):
    if num < 10 :
        return '0'+str(num)
    else:
        return str(num)


def main(v_id,c_id):
    
        
    if sys.version_info[0] == 2:
        reload(sys)
        sys.setdefaultencoding('utf-8')
    
    
    videoId = "804682340" #여기에 원하는 동영상 쿼리명 바꿔주세요
    clientId = "c78irnpyvpes085pcn3homid7mbnuk"
    
    

    chat = []
    time = []
    user = []
    
    nextCursor = ''
    
    params = {}
    params['client_id'] = clientId
    
    
    URL_g = 'https://api.twitch.tv/v5/videos/'+videoId
    response_g = requests.get(URL_g, params=params)
        
    j_g = json.loads(response_g.text)
    
    video_title = j_g['title']
    
    
    i = 0    

    f = open(videoId+".txt", 'w', -1, 'utf-8')
    
    while True :
        if i == 0 :
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?content_offset_seconds=0' 
            i += 1
        else:
            URL = 'https://api.twitch.tv/v5/videos/'+videoId+'/comments?cursor=' 
            URL +=  nextCursor   
            
       
        
        response = requests.get(URL, params=params)
        
        j = json.loads(response.text)
    
        
        for k in range(0,len(j["comments"])):
            timer = j["comments"][k]["content_offset_seconds"]
            
            timeMinute = int(timer/60)
            
            if timeMinute >= 60 :
                timeHour = int(timeMinute/60)
                timeMinute %= 60
            else :
                timeHour = int(timeMinute/60)
    
            timeSec = int(timer%60)
            
            f.write('[')
            f.write(str(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec)))
            #time.append(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec))
            f.write(']')
            f.write(' ')
            f.write('<')
            f.write(str(j["comments"][k]["commenter"]["display_name"]))
            #user.append(j["comments"][k]["commenter"]["display_name"])
            #chat.append(j["comments"][k]["message"]["body"])
            f.write('>')
            f.write(' ')
            f.write(str(j["comments"][k]["message"]["body"]))
            f.write("\n")
            #print(doubleDigit(timeHour)+':'+doubleDigit(timeMinute)+':'+doubleDigit(timeSec), str(j["comments"][k]["commenter"]["display_name"]),j["comments"][k]["message"]["body"])
       
        if '_next' not in j:
            break
        
        nextCursor = j["_next"]
          
    f.close()
    
    
if __name__ == "__main__":
    main(sys.argv[1],sys.argv[2])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-aa6f0ce52252> in <module>
#      98
#      99 if __name__ == "__main__":
# --> 100     main(sys.argv[1],sys.argv[2])
#
# <ipython-input-5-aa6f0ce52252> in main(v_id, c_id)
#      56
#      57
# ---> 58         response = requests.get(URL, params=params)
#      59
#      60         j = json.loads(response.text)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ...
